# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn
import matplotlib

# %%
from sklearn.datasets import fetch_california_housing
var = fetch_california_housing()
var.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
df = pd.DataFrame(var.data, columns=var.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df["MEDV"]=var.target
df.MEDV
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MEDV, Length: 20640, dtype: float64

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
matplotlib.pyplot.figure(figsize=(10, 6))
seaborn.boxplot(data=df)
# Out:
# <Axes: >

# %%
matplotlib.pyplot.figure(figsize=(10, 6))
seaborn.heatmap(data=df)
# Out:
# <Axes: >

# %%
y1=df.MEDV
x1=df.drop('MEDV',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x1, y1, test_size=0.5,random_state = 5 )

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)
pred= pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
import matplotlib.pyplot as plt
plt.plot(pred.Actual,pred.Actual)
plt.plot(pred.Actual[:100],pred.Predicted[:100],'o')

# %%
from sklearn import metrics
metrics.mean_squared_error(pred.Actual,pred.Predicted)
# Out:
# 0.524370715439006
